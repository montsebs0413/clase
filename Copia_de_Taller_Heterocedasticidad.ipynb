# %% [markdown]
# #Taller heterocedasticidad
#
# Nicolas Bocachica David Lozano Sebastian Montaña
#
# -Con el dataset sleep75:\
# Construya un modelo que explique el tiempo de sueño de los individuos del dataset (seleccione las variables que considere relevantes).
# -Verifique si para el modelo construido existe heterocedasticidad.
# Con el dataset hprice1 estime los coeficientes del siguiente modelo:\
# price = \beta_0 + \beta_1lotsize + \beta_2sqrft +\beta_3bdrms + u
# -Con el dataset vote1, estime un modelo cuya variable dependiente sea votea y las variables independientes sean prtystra, democa, log(expenda y log(expendb. Verifique si existe heterocedasticidad.
# -Construya un modelo que explique el tiempo de sueño de los individuos del dataset (seleccione las variables que considere relevantes). Verifique si para el modelo construido existe heterocedasticidad. Corrija la heterocedasticidad haciendo uso de mínimos cuadrados generalizados factibles.
# Verifique si para este nuevo modelo existe heterocedasticidad

# %%
# !pip install wooldridge
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import wooldridge as wd
import statsmodels.api as sm 
import statsmodels.stats.api as sms
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 55.4 MB/s eta 0:00:00
# ...

# %%
df= wd.data("sleep75")
df
# Out:
#      age  black  case  clerical  construc  educ  earns74  gdhlth  inlf  leis1  \
# 0     32      0     1  0.000000  0.000000    12      0.0       0     1   3529
# 1     31      0     2  0.000000  0.000000    14   9500.0       1     1   2140
# 2     44      0     3  0.000000  0.000000    17  42500.0       1     1   4595
# 3     30      0     4  0.000000  0.000000    12  42500.0       1     1   3211
# 4     64      0     5  0.000000  0.000000    14   2500.0       1     1   4052
# ..   ...    ...   ...       ...       ...   ...      ...     ...   ...    ...
# 701   45      0   702  0.182331  0.030075    12   5500.0       1     0   5069
# 702   34      0   703  0.182331  0.030075    10   2500.0       0     0   5885
# 703   37      0   704  0.182331  0.030075    12   3500.0       1     0   4719
# 704   54      0   705  0.182331  0.030075    17  32500.0       1     0   5149
# 705   30      0   706  0.182331  0.030075    16   6750.0       1     0   4747
#
# ...

# %%
wd.data("sleep75",description=True)
# Out:
# name of dataset: sleep75
# no of variables: 34
# no of observations: 706
#
# +----------+--------------------------------+
# | variable | label                          |
# +----------+--------------------------------+
# | age      | in years                       |
# | black    | =1 if black                    |
# | case     | identifier                     |
# | clerical | =1 if clerical worker          |
# | construc | =1 if construction worker      |
# | educ     | years of schooling             |
# | earns74  | total earnings, 1974           |
# | gdhlth   | =1 if in good or excel. health |
# | inlf     | =1 if in labor force           |
# | leis1    | sleep - totwrk                 |
# | leis2    | slpnaps - totwrk               |
# | leis3    | rlxall - totwrk                |
# | smsa     | =1 if live in smsa             |
# | lhrwage  | log hourly wage                |
# | lothinc  | log othinc, unless othinc < 0  |
# | male     | =1 if male                     |
# ...

# %%
X= df [["age","educ","gdhlth","earns74","leis1","totwrk","exper","worknrm"]]
X= sm.add_constant(X)
X.head()
# Out:
#    const  age  educ  gdhlth  earns74  leis1  totwrk  exper  worknrm
# 0    1.0   32    12       0      0.0   3529    3438     14     3438
# 1    1.0   31    14       1   9500.0   2140    5020     11     5020
# 2    1.0   44    17       1  42500.0   4595    2815     21     2815
# 3    1.0   30    12       1  42500.0   3211    3786     12     3786
# 4    1.0   64    14       1   2500.0   4052    2580     44     2580

# %%
y=df["sleep"]
model= sm.OLS(y,X).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  sleep   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 2.150e+24
# Date:                Fri, 12 May 2023   Prob (F-statistic):               0.00
# Time:                        17:13:41   Log-Likelihood:                 12847.
# No. Observations:                 706   AIC:                        -2.568e+04
# Df Residuals:                     698   BIC:                        -2.564e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        775.3846   1.52e-10    5.1e+12      0.000     775.385     775.385
# ...

# %%
sms.het_white(model.resid,model.model.exog)
# Out:
# (705.9980141082152, 1.4398568731083916e-126, 7016031.065786809, 0.0)

# %%
sms.het_breuschpagan(model.resid,model.model.exog)
# Out:
# (506.10979836396467,
#  3.437996082806918e-104,
#  252.47048941775677,
#  1.6754699831191577e-186)

# %%
df1= wd.data("hprice1")
df1
# Out:
#     price      assess  bdrms  lotsize  sqrft  colonial    lprice   lassess  \
# 0   300.0  349.100006      4   6126.0   2438         1  5.703783  5.855359
# 1   370.0  351.500000      3   9903.0   2076         1  5.913503  5.862210
# 2   191.0  217.699997      3   5200.0   1374         0  5.252274  5.383118
# 3   195.0  231.800003      3   4600.0   1448         1  5.273000  5.445875
# 4   373.0  319.100006      4   6095.0   2514         1  5.921578  5.765504
# ..    ...         ...    ...      ...    ...       ...       ...       ...
# 83  295.0  318.299988      3   6056.0   1837         1  5.686975  5.762994
# 84  236.0  259.399994      3   5828.0   1715         0  5.463832  5.558371
# 85  202.5  258.100006      3   6341.0   1574         0  5.310740  5.553347
# 86  219.0  232.000000      2   6362.0   1185         0  5.389072  5.446737
# 87  242.0  252.000000      4   4950.0   1774         1  5.488938  5.529429
#
#     llotsize    lsqrft
# 0   8.720297  7.798934
# ...

# %%
X= df1 [["lotsize","sqrft","bdrms"]]
X= sm.add_constant(X)
X.head()
# Out:
#    const  lotsize  sqrft  bdrms
# 0    1.0   6126.0   2438      4
# 1    1.0   9903.0   2076      3
# 2    1.0   5200.0   1374      3
# 3    1.0   4600.0   1448      3
# 4    1.0   6095.0   2514      4

# %%
y=df1["price"]

betas=np.linalg.inv(X.T.dot(X)).dot(X.T.dot(y))
betas
# Out:
# array([-2.17703081e+01,  2.06770661e-03,  1.22778185e-01,  1.38525217e+01])

# %%
sms.het_white(model.resid,model.model.exog)
# Out:
# (705.9980141082152, 1.4398568731083916e-126, 7016031.065786809, 0.0)

# %%
sms.het_breuschpagan(model.resid,model.model.exog)
# Out:
# (506.10979836396467,
#  3.437996082806918e-104,
#  252.47048941775677,
#  1.6754699831191577e-186)

# %%
df2= wd.data("vote1")
df2
# Out:
#     state  district  democA  voteA     expendA      expendB  prtystrA  \
# 0      AL         7       1     68  328.295990     8.737000        41
# 1      AK         1       0     62  626.377014   402.476990        60
# 2      AZ         2       1     73   99.607002     3.065000        55
# 3      AZ         3       0     69  319.690002    26.281000        64
# 4      AR         3       0     75  159.220993    60.054001        66
# ..    ...       ...     ...    ...         ...          ...       ...
# 168    WV         4       0     39   32.039001   152.270996        42
# 169    WI         3       1     32   22.625999   359.800995        53
# 170    WI         5       0     36  197.460007  1278.526001        36
# 171    WI         7       0     38  202.591003   450.716003        46
# 172    WI         8       1     30   14.421000   227.822998        47
#
#      lexpendA  lexpendB     shareA
# 0    5.793916  2.167567  97.407669
# 1    6.439952  5.997638  60.881039
# ...

# %%
X= df2 [["prtystrA","democA","lexpendA","lexpendB"]]
X= sm.add_constant(X)
X.head()
# Out:
#    const  prtystrA  democA  lexpendA  lexpendB
# 0    1.0        41       1  5.793916  2.167567
# 1    1.0        60       0  6.439952  5.997638
# 2    1.0        55       1  4.601233  1.120048
# 3    1.0        64       0  5.767352  3.268846
# 4    1.0        66       0  5.070293  4.095244

# %%
y=df2["voteA"]

model= sm.OLS(y,X).fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  voteA   R-squared:                       0.801
# Model:                            OLS   Adj. R-squared:                  0.796
# Method:                 Least Squares   F-statistic:                     169.2
# Date:                Fri, 12 May 2023   Prob (F-statistic):           8.09e-58
# Time:                        17:17:01   Log-Likelihood:                -593.20
# No. Observations:                 173   AIC:                             1196.
# Df Residuals:                     168   BIC:                             1212.
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         37.6614      4.736      7.952      0.000      28.312      47.011
# ...

# %%
sms.het_white(model.resid,model.model.exog)
# Out:
# (31.101514031882232,
#  0.0032582637988174596,
#  2.680757572966291,
#  0.00197332657011948)

# %%
sms.het_breuschpagan(model.resid,model.model.exog)
# Out:
# (9.093356486631858,
#  0.05880790411089852,
#  2.330112826740845,
#  0.058057501107010134)

# %%
df3= wd.data("fertil2")
df3
# Out:
#       mnthborn  yearborn  age  electric  radio   tv  bicycle  educ  ceb  \
# 0            5        64   24       1.0    1.0  1.0      1.0    12    0
# 1            1        56   32       1.0    1.0  1.0      1.0    13    3
# 2            7        58   30       1.0    0.0  0.0      0.0     5    1
# 3           11        45   42       1.0    0.0  1.0      0.0     4    3
# 4            5        45   43       1.0    1.0  1.0      1.0    11    2
# ...        ...       ...  ...       ...    ...  ...      ...   ...  ...
# 4356         6        72   16       0.0    1.0  0.0      0.0     7    0
# 4357         1        60   28       0.0    1.0  0.0      0.0     7    2
# 4358        11        63   24       0.0    1.0  0.0      0.0     5    4
# 4359         1        62   26       0.0    1.0  0.0      0.0     0    1
# 4360        12        51   36       0.0    1.0  0.0      0.0     3    6
#
#       agefbrth  ...  heduc  agesq  urban  urb_educ  spirit  protest  catholic  \
# ...

# %%
X= df3 [["mnthborn","age","educ","ceb","urb_educ", "yearborn"]]
X= sm.add_constant(X)
X.head()
# Out:
#    const  mnthborn  age  educ  ceb  urb_educ  yearborn
# 0    1.0         5   24    12    0        12        64
# 1    1.0         1   32    13    3        13        56
# 2    1.0         7   30     5    1         5        58
# 3    1.0        11   42     4    3         4        45
# 4    1.0         5   43    11    2        11        45

# %% [markdown]
# # CONCLUSIONES

# %% [markdown]
# 1. Con las pruebas se puede afirmar que el modelo es heterocedastico, puesto que el p-valor se encuentra por debajo del 5%. Por lo que, rechazo la hipótesis Nula y concluyo que alguna de las variables está afectando los minutos de sueño de los individuos por semana.
# 2. Con las dos pruebas se puede afirmar que el modelo es heterocedastico, puesto que el p-valor se encuentra por debajo del 5%. Por lo que, rechazo la hipótesis  y que alguna de las variables está afectando el precio.
# 3. Con las dos pruebas se puede afirmar que el modelo es heterocedastico, puesto que el p-valor se encuentra por debajo del 5%. Por lo que, rechazo la hipótesis Nula, ya que alguna de las variables está afectando el porcentaje por voto A.
